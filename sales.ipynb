# %%
import pandas as pd

df = pd.read_excel('Data.xlsx')
df
# Out:
#        InvoiceID  CompanyRef  SalesOfficeRef  SalesAreaRef  \
# 0             62           1               2             2
# 1             62           1               2             2
# 2             64           1               2             2
# 3             64           1               2             2
# 4             67           1               2             2
# ...          ...         ...             ...           ...
# 17289       5256           1               2             5
# 17290       5257           1               2             5
# 17291       5257           1               2             5
# 17292       5257           1               2             5
# 17293       5257           1               2             5
#
#        OperationalCurrencyExchangeRate                     Date  CustomerRef  \
# 0                                  1.0  2022-02-06 00:00:00.000            5
# 1                                  1.0  2022-02-06 00:00:00.000            5
# 2                                  1.0  2022-03-02 00:00:00.000        18806
# 3                                  1.0  2022-03-02 00:00:00.000        18806
# 4                                  1.0  2022-02-22 00:00:00.000        13704
# ...                                ...                      ...          ...
# 17289                              1.0  2025-04-28 00:00:00.000        94012
# 17290                              1.0  2025-04-28 00:00:00.000        94012
# 17291                              1.0  2025-04-28 00:00:00.000        94012
# 17292                              1.0  2025-04-28 00:00:00.000        94012
# 17293                              1.0  2025-04-28 00:00:00.000        94012
#
#        PayerAccountRef  RecipientRef  InvoicePrice  ...  InvoiceItemPrice  \
# 0                   29           5.0  9.500000e+07  ...      9.500000e+07
# 1                   29           5.0  9.500000e+07  ...      9.500000e+07
# 2                   43       18806.0  1.750000e+10  ...      1.750000e+10
# 3                   43       18806.0  1.750000e+10  ...      1.750000e+10
# 4                   34       13704.0  2.000000e+07  ...      2.000000e+07
# ...                ...           ...           ...  ...               ...
# 17289             1481       94012.0  1.050000e+08  ...      6.000000e+07
# 17290             1481       94012.0  8.000000e+07  ...      5.000000e+07
# 17291             1481       94012.0  8.000000e+07  ...      5.000000e+07
# 17292             1481       94012.0  8.000000e+07  ...      3.000000e+07
# 17293             1481       94012.0  8.000000e+07  ...      3.000000e+07
#
#        EffectiveNetPrice.1      NetPrice  RegionalDivisionRef  ProductUnitRef  \
# 0             1.035500e+08  1.035500e+08                  342               2
# 1             1.035500e+08  1.035500e+08                  342               2
# 2             1.907500e+10  1.907500e+10                    3               2
# 3             1.907500e+10  1.907500e+10                    3               2
# 4             2.180000e+07  2.180000e+07                    3               1
# ...                    ...           ...                  ...             ...
# 17289         6.600000e+07  6.600000e+07                  623               1
# 17290         5.500000e+07  5.500000e+07                  623               1
# 17291         5.500000e+07  5.500000e+07                  623               1
# 17292         3.300000e+07  3.300000e+07                  623               1
# 17293         3.300000e+07  3.300000e+07                  623               1
#
#        PriceBaseUnitRef  ProductPackItemRef  ParentRef  HasReservation  \
# 0                     2                 NaN        NaN               0
# 1                     2                 NaN        NaN               0
# 2                     2                 NaN        NaN               0
# 3                     2                 NaN        NaN               0
# 4                     1                 NaN        NaN               0
# ...                 ...                 ...        ...             ...
# 17289                 1                 NaN        NaN               0
# 17290                 1                 NaN        NaN               0
# 17291                 1                 NaN        NaN               0
# 17292                 1                 NaN        NaN               0
# 17293                 1                 NaN        NaN               0
#
#        BatchRef
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 17289       NaN
# 17290       NaN
# 17291       NaN
# 17292       NaN
# 17293       NaN
#
# [17294 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17294 entries, 0 to 17293
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   InvoiceID                        17294 non-null  int64
#  1   CompanyRef                       17294 non-null  int64
#  2   SalesOfficeRef                   17294 non-null  int64
#  3   SalesAreaRef                     17294 non-null  int64
#  4   OperationalCurrencyExchangeRate  17294 non-null  float64
#  5   Date                             17294 non-null  object
#  6   CustomerRef                      17294 non-null  int64
#  7   PayerAccountRef                  17294 non-null  int64
#  8   RecipientRef                     17277 non-null  float64
#  9   InvoicePrice                     17294 non-null  float64
#  10  InvoiceAdditionAmount            17294 non-null  float64
#  11  InvoiceReductionAmount           17294 non-null  float64
#  12  EffectiveNetPrice                17294 non-null  float64
#  13  InvoiceNetPrice                  17294 non-null  float64
#  14  Status                           17294 non-null  int64
#  15  Creator                          17294 non-null  int64
#  16  InvoiceItemID                    17294 non-null  int64
#  17  InvoiceRef                       17294 non-null  int64
#  18  RowNumber                        17294 non-null  int64
#  19  ProductRef                       17294 non-null  int64
#  20  PriceBaseFee                     17294 non-null  float64
#  21  Quantity                         17294 non-null  float64
#  22  MajorUnitInitialQuantity         17294 non-null  float64
#  23  MajorUnitQuantity                17294 non-null  float64
#  24  InitialQuantity                  17294 non-null  float64
#  25  InvoiceItemFee                   17294 non-null  float64
#  26  InvoiceItemPrice                 17294 non-null  float64
#  27  EffectiveNetPrice.1              17294 non-null  float64
#  28  NetPrice                         17294 non-null  float64
#  29  RegionalDivisionRef              17294 non-null  int64
#  30  ProductUnitRef                   17294 non-null  int64
#  31  PriceBaseUnitRef                 17294 non-null  int64
#  32  ProductPackItemRef               0 non-null      float64
#  33  ParentRef                        0 non-null      float64
#  34  HasReservation                   17294 non-null  int64
#  35  BatchRef                         0 non-null      float64
# dtypes: float64(19), int64(16), object(1)
# memory usage: 4.8+ MB

# %%
columns = ['CompanyRef', 'SalesOfficeRef', 'OperationalCurrencyExchangeRate', 'RecipientRef', 'Status', 'InvoiceRef', 'PriceBaseFee', 'MajorUnitInitialQuantity', 'MajorUnitQuantity', 'InitialQuantity', 'ProductUnitRef', 'PriceBaseUnitRef', 'ProductPackItemRef', 'ParentRef', 'HasReservation', 'BatchRef']
df.drop(columns=columns, inplace=True)
# missing = [col for col in columns if col not in df.columns]
# print("ستون‌های موجود نیست:", missing)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 columns = ['CompanyRef', 'SalesOfficeRef', 'OperationalCurrencyExchangeRate', 'RecipientRef', 'Status', 'InvoiceRef', 'PriceBaseFee', 'MajorUnitInitialQuantity', 'MajorUnitQuantity', 'InitialQuantity', 'ProductUnitRef', 'PriceBaseUnitRef', 'ProductPackItemRef', 'ParentRef', 'HasReservation', 'BatchRef']
# ----> 2 df.drop(columns=columns, inplace=True)
#       3 # missing = [col for col in columns if col not in df.columns]
#       4 # print("ستون‌های موجود نیست:", missing)
#       6 df
#
# File D:\MFTProject\SLSProject\venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File D:\MFTProject\SLSProject\venv\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File D:\MFTProject\SLSProject\venv\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File D:\MFTProject\SLSProject\venv\Lib\site-packages\pandas\core\indexes\base.py:7098, in Index.drop(self, labels, errors)
#    7096 if mask.any():
#    7097     if errors != "ignore":
# -> 7098         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7099     indexer = indexer[~mask]
#    7100 return self.delete(indexer)
#
# KeyError: "['CompanyRef', 'SalesOfficeRef', 'OperationalCurrencyExchangeRate', 'RecipientRef', 'Status', 'InvoiceRef', 'PriceBaseFee', 'MajorUnitInitialQuantity', 'MajorUnitQuantity', 'InitialQuantity', 'ProductUnitRef', 'PriceBaseUnitRef', 'ProductPackItemRef', 'ParentRef', 'HasReservation', 'BatchRef'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17294 entries, 0 to 17293
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   InvoiceID               17294 non-null  int64
#  1   SalesAreaRef            17294 non-null  int64
#  2   Date                    17294 non-null  object
#  3   CustomerRef             17294 non-null  int64
#  4   PayerAccountRef         17294 non-null  int64
#  5   InvoicePrice            17294 non-null  float64
#  6   InvoiceAdditionAmount   17294 non-null  float64
#  7   InvoiceReductionAmount  17294 non-null  float64
#  8   EffectiveNetPrice       17294 non-null  float64
#  9   InvoiceNetPrice         17294 non-null  float64
#  10  Creator                 17294 non-null  int64
#  11  InvoiceItemID           17294 non-null  int64
#  12  RowNumber               17294 non-null  int64
#  13  ProductRef              17294 non-null  int64
#  14  Quantity                17294 non-null  float64
#  15  InvoiceItemFee          17294 non-null  float64
#  16  InvoiceItemPrice        17294 non-null  float64
#  17  EffectiveNetPrice.1     17294 non-null  float64
#  18  NetPrice                17294 non-null  float64
#  19  RegionalDivisionRef     17294 non-null  int64
# dtypes: float64(10), int64(9), object(1)
# memory usage: 2.6+ MB
